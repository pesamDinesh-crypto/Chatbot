# %%
import nltk
import os

# NLTK data location
download_dir = r"C:\Users\pesam\AppData\Roaming\nltk_data"

# Create folder if it doesn't exist
os.makedirs(download_dir, exist_ok=True)

# Download required resources
nltk.download('punkt_tab', download_dir=download_dir)
nltk.download('punkt', download_dir=download_dir)
nltk.download('wordnet', download_dir=download_dir)

# Add the location to NLTK search path
if download_dir not in nltk.data.path:
    nltk.data.path.append(download_dir)

print("NLTK resources downloaded successfully!")
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\pesam\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.
# NLTK resources downloaded successfully!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\pesam\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\pesam\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
import nltk

print(nltk.data.find("tokenizers/punkt_tab/english/"))
# Out:
# C:\Users\pesam\AppData\Roaming\nltk_data\tokenizers\punkt_tab\english

# %%
import nltk
import string
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# Download required NLTK data
nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('wordnet')

# -----------------------------
# Sample corpus
# -----------------------------
corpus = """Hello! How can I help you?
What is your name?
I’m a chatbot built using Python.
Tell me a joke.
Python is a great programming language.
Goodbye!"""

# Split corpus into sentences
sent_tokens = nltk.sent_tokenize(corpus)

# -----------------------------
# Lemmatizer
# -----------------------------
lemmer = nltk.stem.WordNetLemmatizer()

def LemTokens(tokens):
    return [
        lemmer.lemmatize(token.lower())
        for token in tokens
        if token not in string.punctuation
    ]

# -----------------------------
# Chatbot response function
# -----------------------------
def respond(user_input):

    # Add user's question temporarily
    sent_tokens.append(user_input)

    # Create TF-IDF vectorizer
    vectorizer = TfidfVectorizer(
        stop_words="english",
        lowercase=True
    )

    # Convert sentences into TF-IDF vectors
    tfidf_matrix = vectorizer.fit_transform(sent_tokens)

    # Compare user's input with existing sentences
    vals = cosine_similarity(
        tfidf_matrix[-1],
        tfidf_matrix[:-1]
    )

    # Find most similar sentence
    idx = vals.argmax()

    # Get response
    response = sent_tokens[idx]

    # Remove user's input
    sent_tokens.pop()

    return response


# -----------------------------
# Chat loop
# -----------------------------
print("ChatBot: Ask me anything! Type 'bye' to exit.")

while True:

    user_input = input("You: ")

    if user_input.lower() == "bye":
        print("ChatBot: Goodbye!")
        break

    else:
        print("ChatBot:", respond(user_input))
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\pesam\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\pesam\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\pesam\AppData\Roaming\nltk_data...
# ChatBot: Ask me anything! Type 'bye' to exit.
# [nltk_data]   Package wordnet is already up-to-date!
# You:  hello
# ChatBot: Hello!
# You:  how are you
# ChatBot: Hello!
# You:  how to create website
# ChatBot: Hello!
